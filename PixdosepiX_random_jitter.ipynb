# %% [markdown]
# # PixdosepiX-OpenKBP---2020-AAPM-Grand-Challenge-

# %% [markdown]
# ## Introduction

# %% [markdown]
# The aim of the OpenKBP Challenge is to advance fair and consistent comparisons of dose prediction methods for knowledge-based planning (KBP). Participants of the challenge will use a large dataset to train, test, and compare their prediction methods, using a set of standardized metrics, with those of other participants.

# %% [markdown]
# ## Get and prepare data

# %%
# !wget "https://competitions.codalab.org/my/datasets/download/e25ae3d9-03e1-4d2c-8af2-f9991193f54b"
# Out:
# --2020-05-30 12:31:14--  https://competitions.codalab.org/my/datasets/download/e25ae3d9-03e1-4d2c-8af2-f9991193f54b
# Resolving competitions.codalab.org (competitions.codalab.org)... 129.175.22.230
# Connecting to competitions.codalab.org (competitions.codalab.org)|129.175.22.230|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://newcodalab.lri.fr/prod-private/public_data/38960/b9a18/competition/23428/1/data/public_dat.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=696e85df42dfb58f502a163791dff879486f262735ad6ea49db1ed875916bb87&X-Amz-Date=20200530T123115Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200530%2Fnewcodalab%2Fs3%2Faws4_request [following]
# --2020-05-30 12:31:15--  https://newcodalab.lri.fr/prod-private/public_data/38960/b9a18/competition/23428/1/data/public_dat.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=696e85df42dfb58f502a163791dff879486f262735ad6ea49db1ed875916bb87&X-Amz-Date=20200530T123115Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200530%2Fnewcodalab%2Fs3%2Faws4_request
# Resolving newcodalab.lri.fr (newcodalab.lri.fr)... 129.175.15.21
# Connecting to newcodalab.lri.fr (newcodalab.lri.fr)|129.175.15.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 419570351 (400M) [application/zip]
# Saving to: ‘e25ae3d9-03e1-4d2c-8af2-f9991193f54b’
#
# e25ae3d9-03e1-4d2c- 100%[===================>] 400.13M  11.2MB/s    in 38s
#
# 2020-05-30 12:31:55 (10.4 MB/s) - ‘e25ae3d9-03e1-4d2c-8af2-f9991193f54b’ saved [419570351/419570351]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mv /content/e25ae3d9-03e1-4d2c-8af2-f9991193f54b train.zip
# !unzip train.zip
# !rm "/content/train-pats/.DS_Store"
# !rm "/content/validation-pats-no-dose/.DS_Store"
# Out:
# Archive:  train.zip
#    creating: train-pats/
#    creating: validation-pats-no-dose/
#   inflating: .DS_Store
#    creating: validation-pats-no-dose/pt_201/
#    creating: validation-pats-no-dose/pt_202/
#    creating: validation-pats-no-dose/pt_203/
#    creating: validation-pats-no-dose/pt_204/
#    creating: validation-pats-no-dose/pt_205/
#    creating: validation-pats-no-dose/pt_206/
#    creating: validation-pats-no-dose/pt_207/
#    creating: validation-pats-no-dose/pt_208/
#    creating: validation-pats-no-dose/pt_209/
#    creating: validation-pats-no-dose/pt_210/
#    creating: validation-pats-no-dose/pt_211/
#    creating: validation-pats-no-dose/pt_212/
#    creating: validation-pats-no-dose/pt_213/
#    creating: validation-pats-no-dose/pt_214/
#    creating: validation-pats-no-dose/pt_215/
#    creating: validation-pats-no-dose/pt_216/
#    creating: validation-pats-no-dose/pt_217/
#    creating: validation-pats-no-dose/pt_218/
#    creating: validation-pats-no-dose/pt_219/
#    creating: train-pats/pt_117/
#    creating: train-pats/pt_118/
#    creating: train-pats/pt_119/
#    creating: train-pats/pt_12/
#    creating: train-pats/pt_120/
#    creating: train-pats/pt_121/
#    creating: train-pats/pt_122/
#    creating: train-pats/pt_123/
#    creating: train-pats/pt_124/
#    creating: train-pats/pt_125/
#    creating: train-pats/pt_126/
#    creating: train-pats/pt_127/
#    creating: train-pats/pt_128/
#    creating: train-pats/pt_129/
#    creating: train-pats/pt_13/
#    creating: train-pats/pt_130/
#    creating: train-pats/pt_131/
#    creating: train-pats/pt_132/
#    creating: train-pats/pt_133/
#    creating: train-pats/pt_134/
#    creating: train-pats/pt_135/
#    creating: train-pats/pt_136/
#    creating: train-pats/pt_137/
#    creating: train-pats/pt_138/
#    creating: train-pats/pt_139/
#    creating: train-pats/pt_14/
#    creating: train-pats/pt_140/
#    creating: train-pats/pt_141/
#    creating: train-pats/pt_142/
#    creating: train-pats/pt_143/
#    creating: train-pats/pt_144/
#    creating: train-pats/pt_145/
#    creating: train-pats/pt_146/
#    creating: train-pats/pt_147/
#    creating: train-pats/pt_148/
#    creating: train-pats/pt_149/
#    creating: train-pats/pt_15/
#    creating: train-pats/pt_150/
#    creating: train-pats/pt_151/
#    creating: train-pats/pt_152/
#    creating: train-pats/pt_153/
#    creating: train-pats/pt_154/
#    creating: train-pats/pt_155/
#    creating: train-pats/pt_156/
#    creating: train-pats/pt_157/
#    creating: train-pats/pt_158/
#    creating: train-pats/pt_159/
#    creating: train-pats/pt_16/
#    creating: train-pats/pt_160/
#    creating: train-pats/pt_161/
#    creating: train-pats/pt_162/
#    creating: train-pats/pt_163/
#    creating: train-pats/pt_164/
#    creating: train-pats/pt_165/
#    creating: train-pats/pt_166/
#    creating: train-pats/pt_167/
#    creating: train-pats/pt_168/
#    creating: train-pats/pt_169/
#    creating: train-pats/pt_17/
#    creating: train-pats/pt_170/
#    creating: train-pats/pt_171/
#    creating: train-pats/pt_172/
#    creating: train-pats/pt_173/
#    creating: train-pats/pt_174/
#    creating: train-pats/pt_175/
#    creating: train-pats/pt_176/
#    creating: train-pats/pt_177/
#    creating: train-pats/pt_178/
#    creating: train-pats/pt_179/
#    creating: train-pats/pt_18/
#    creating: train-pats/pt_180/
#    creating: train-pats/pt_181/
#    creating: train-pats/pt_182/
#    creating: train-pats/pt_183/
#    creating: train-pats/pt_184/
#    creating: train-pats/pt_185/
#    creating: train-pats/pt_186/
#    creating: train-pats/pt_187/
#    creating: train-pats/pt_188/
#    creating: train-pats/pt_189/
#    creating: train-pats/pt_19/
#    creating: train-pats/pt_190/
#    creating: train-pats/pt_191/
#    creating: train-pats/pt_192/
#    creating: train-pats/pt_193/
#    creating: train-pats/pt_194/
#    creating: train-pats/pt_195/
#    creating: train-pats/pt_196/
#    creating: train-pats/pt_197/
#    creating: train-pats/pt_198/
#    creating: train-pats/pt_199/
#    creating: train-pats/pt_2/
#    creating: train-pats/pt_20/
#    creating: train-pats/pt_200/
#    creating: train-pats/pt_21/
#    creating: train-pats/pt_22/
#    creating: train-pats/pt_23/
#    creating: train-pats/pt_24/
#    creating: train-pats/pt_25/
#    creating: train-pats/pt_26/
#    creating: train-pats/pt_27/
#    creating: train-pats/pt_28/
#    creating: train-pats/pt_29/
#    creating: train-pats/pt_3/
#    creating: train-pats/pt_30/
#    creating: train-pats/pt_31/
#    creating: train-pats/pt_32/
#    creating: train-pats/pt_33/
#    creating: train-pats/pt_34/
#    creating: train-pats/pt_35/
#    creating: train-pats/pt_36/
#    creating: train-pats/pt_37/
#    creating: train-pats/pt_38/
#    creating: train-pats/pt_39/
#    creating: train-pats/pt_4/
#    creating: train-pats/pt_40/
#    creating: train-pats/pt_41/
#    creating: train-pats/pt_42/
#    creating: train-pats/pt_43/
#    creating: train-pats/pt_44/
#    creating: train-pats/pt_45/
#    creating: train-pats/pt_46/
#    creating: train-pats/pt_47/
#    creating: train-pats/pt_48/
#    creating: train-pats/pt_49/
#    creating: train-pats/pt_5/
#    creating: train-pats/pt_50/
#    creating: train-pats/pt_51/
#    creating: train-pats/pt_52/
#    creating: train-pats/pt_53/
#    creating: train-pats/pt_54/
#    creating: train-pats/pt_55/
#    creating: train-pats/pt_56/
#    creating: train-pats/pt_57/
#    creating: train-pats/pt_58/
#    creating: train-pats/pt_59/
#    creating: train-pats/pt_6/
#    creating: train-pats/pt_60/
#    creating: train-pats/pt_61/
#    creating: train-pats/pt_62/
#    creating: train-pats/pt_63/
#    creating: train-pats/pt_64/
#    creating: train-pats/pt_65/
#    creating: train-pats/pt_66/
#    creating: train-pats/pt_67/
#    creating: train-pats/pt_68/
#    creating: train-pats/pt_69/
#    creating: train-pats/pt_7/
#    creating: train-pats/pt_70/
#    creating: train-pats/pt_71/
#    creating: train-pats/pt_72/
#    creating: train-pats/pt_73/
#    creating: train-pats/pt_74/
#    creating: train-pats/pt_75/
#    creating: train-pats/pt_76/
#    creating: train-pats/pt_77/
#    creating: train-pats/pt_78/
#    creating: train-pats/pt_79/
#    creating: train-pats/pt_8/
#    creating: train-pats/pt_80/
#    creating: train-pats/pt_81/
#    creating: train-pats/pt_82/
#    creating: train-pats/pt_83/
#    creating: train-pats/pt_84/
#    creating: train-pats/pt_85/
#    creating: train-pats/pt_86/
#    creating: train-pats/pt_87/
#    creating: train-pats/pt_88/
#    creating: train-pats/pt_89/
#    creating: train-pats/pt_9/
#    creating: train-pats/pt_90/
#    creating: train-pats/pt_91/
#    creating: train-pats/pt_92/
#    creating: train-pats/pt_93/
#    creating: train-pats/pt_94/
#    creating: train-pats/pt_95/
#    creating: train-pats/pt_96/
#    creating: train-pats/pt_97/
#    creating: train-pats/pt_98/
#    creating: train-pats/pt_99/
#   inflating: train-pats/.DS_Store
#   inflating: train-pats/pt_40/possible_dose_mask.csv
#   inflating: train-pats/pt_40/RightParotid.csv
#   inflating: train-pats/pt_40/ct.csv
#   inflating: train-pats/pt_40/voxel_dimensions.csv
#   inflating: train-pats/pt_40/PTV56.csv
#   inflating: train-pats/pt_40/LeftParotid.csv
#   inflating: train-pats/pt_40/SpinalCord.csv
#   inflating: train-pats/pt_40/Brainstem.csv
#   inflating: train-pats/pt_35/PTV70.csv
#   inflating: train-pats/pt_35/dose.csv
#   inflating: train-pats/pt_35/PTV63.csv

# %%
# !wget "https://competitions.codalab.org/my/datasets/download/3ed63c9e-1046-41e3-b151-196e35adb4b1"
# Out:
# --2020-05-30 12:32:46--  https://competitions.codalab.org/my/datasets/download/3ed63c9e-1046-41e3-b151-196e35adb4b1
# Resolving competitions.codalab.org (competitions.codalab.org)... 129.175.22.230
# Connecting to competitions.codalab.org (competitions.codalab.org)|129.175.22.230|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://newcodalab.lri.fr/prod-private/public_data/38961/2fece/competition/23428/2/data/public_dat.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=1eaa0750a02f63cf6aa1bae74fbc330b87f7178e89f3942d9a8c31ce469c8d29&X-Amz-Date=20200530T123247Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200530%2Fnewcodalab%2Fs3%2Faws4_request [following]
# --2020-05-30 12:32:48--  https://newcodalab.lri.fr/prod-private/public_data/38961/2fece/competition/23428/2/data/public_dat.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=1eaa0750a02f63cf6aa1bae74fbc330b87f7178e89f3942d9a8c31ce469c8d29&X-Amz-Date=20200530T123247Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200530%2Fnewcodalab%2Fs3%2Faws4_request
# Resolving newcodalab.lri.fr (newcodalab.lri.fr)... 129.175.15.21
# Connecting to newcodalab.lri.fr (newcodalab.lri.fr)|129.175.15.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117581259 (112M) [application/zip]
# Saving to: ‘3ed63c9e-1046-41e3-b151-196e35adb4b1’
#
# 3ed63c9e-1046-41e3- 100%[===================>] 112.13M  10.5MB/s    in 12s
#
# 2020-05-30 12:33:01 (9.28 MB/s) - ‘3ed63c9e-1046-41e3-b151-196e35adb4b1’ saved [117581259/117581259]

# %%
# !mv /content/3ed63c9e-1046-41e3-b151-196e35adb4b1 test.zip
# !mkdir testeo
# !cp test.zip testeo

# %%
cd testeo/
# Out:
# /content/testeo

# %%
# !unzip /content/testeo/test.zip
# Out:
# Archive:  /content/testeo/test.zip
#    creating: pt_241/
#    creating: pt_242/
#    creating: pt_243/
#    creating: pt_244/
#    creating: pt_245/
#    creating: pt_246/
#    creating: pt_247/
#    creating: pt_248/
#    creating: pt_249/
#    creating: pt_250/
#    creating: pt_251/
#    creating: pt_252/
#    creating: pt_253/
#    creating: pt_254/
#    creating: pt_255/
#    creating: pt_256/
#    creating: pt_257/
#    creating: pt_258/
#    creating: pt_259/
#    creating: pt_260/
#    creating: pt_261/
#    creating: pt_262/
#    creating: pt_263/
#    creating: pt_264/
#    creating: pt_265/
#    creating: pt_266/
#    creating: pt_267/
#    creating: pt_268/
#    creating: pt_269/
#    creating: pt_270/
#    creating: pt_271/
#    creating: pt_272/
#    creating: pt_273/
#    creating: pt_274/
#    creating: pt_275/
#    creating: pt_276/
#    creating: pt_277/
#    creating: pt_278/
#    creating: pt_279/
#    creating: pt_280/
#    creating: pt_281/
#    creating: pt_282/
#    creating: pt_283/
#    creating: pt_284/
#    creating: pt_285/
#    creating: pt_286/
#    creating: pt_287/
#    creating: pt_288/
#    creating: pt_289/
#    creating: pt_290/
#    creating: pt_291/
#    creating: pt_292/
#    creating: pt_293/
#    creating: pt_294/
#    creating: pt_295/
#    creating: pt_296/
#    creating: pt_297/
#    creating: pt_298/
#    creating: pt_299/
#    creating: pt_300/
#    creating: pt_301/
#    creating: pt_302/
#    creating: pt_303/
#    creating: pt_304/
#    creating: pt_305/
#    creating: pt_306/
#    creating: pt_307/
#    creating: pt_308/
#    creating: pt_309/
#    creating: pt_310/
#    creating: pt_311/
#    creating: pt_312/
#    creating: pt_313/
#    creating: pt_314/
#    creating: pt_315/
#    creating: pt_316/
#    creating: pt_317/
#    creating: pt_318/
#    creating: pt_319/
#    creating: pt_320/
#    creating: pt_321/
#    creating: pt_322/
#    creating: pt_323/
#    creating: pt_324/
#    creating: pt_325/
#    creating: pt_326/
#    creating: pt_327/
#    creating: pt_328/
#    creating: pt_329/
#    creating: pt_330/
#    creating: pt_331/
#    creating: pt_332/
#    creating: pt_333/
#    creating: pt_334/
#    creating: pt_335/
#    creating: pt_336/
#    creating: pt_337/
#    creating: pt_338/
#    creating: pt_339/
#    creating: pt_340/
#   inflating: .DS_Store
#   inflating: pt_289/possible_dose_mask.csv
#   inflating: pt_289/RightParotid.csv
#   inflating: pt_289/ct.csv
#   inflating: pt_289/voxel_dimensions.csv
#   inflating: pt_289/PTV56.csv
#   inflating: pt_289/LeftParotid.csv
#   inflating: pt_289/SpinalCord.csv
#   inflating: pt_289/Brainstem.csv
#   inflating: pt_289/PTV70.csv
#   inflating: pt_289/PTV63.csv
#   inflating: pt_242/Larynx.csv
#   inflating: pt_242/possible_dose_mask.csv
#   inflating: pt_242/RightParotid.csv
#   inflating: pt_242/Esophagus.csv
#   inflating: pt_242/ct.csv
#   inflating: pt_242/voxel_dimensions.csv
#   inflating: pt_242/PTV56.csv
#   inflating: pt_242/LeftParotid.csv
#   inflating: pt_242/SpinalCord.csv
#   inflating: pt_242/Brainstem.csv
#   inflating: pt_242/PTV70.csv
#   inflating: pt_245/Larynx.csv
#   inflating: pt_245/possible_dose_mask.csv
#   inflating: pt_245/RightParotid.csv
#   inflating: pt_245/ct.csv
#   inflating: pt_245/voxel_dimensions.csv
#   inflating: pt_245/PTV56.csv
#   inflating: pt_245/LeftParotid.csv
#   inflating: pt_245/SpinalCord.csv
#   inflating: pt_245/PTV70.csv
#   inflating: pt_245/Mandible.csv
#   inflating: pt_245/PTV63.csv
#   inflating: pt_287/possible_dose_mask.csv
#   inflating: pt_287/RightParotid.csv
#   inflating: pt_287/ct.csv
#   inflating: pt_287/voxel_dimensions.csv
#   inflating: pt_287/PTV56.csv
#   inflating: pt_287/LeftParotid.csv
#   inflating: pt_287/SpinalCord.csv
#   inflating: pt_287/Brainstem.csv
#   inflating: pt_287/PTV70.csv
#   inflating: pt_287/PTV63.csv
#   inflating: pt_273/possible_dose_mask.csv
#   inflating: pt_273/RightParotid.csv
#   inflating: pt_273/ct.csv
#   inflating: pt_273/voxel_dimensions.csv
#   inflating: pt_273/LeftParotid.csv
#   inflating: pt_273/SpinalCord.csv
#   inflating: pt_273/Brainstem.csv
#   inflating: pt_297/SpinalCord.csv
#   inflating: pt_297/Brainstem.csv
#   inflating: pt_297/PTV70.csv
#   inflating: pt_297/Mandible.csv
#   inflating: pt_297/PTV63.csv
#   inflating: pt_290/possible_dose_mask.csv
#   inflating: pt_290/RightParotid.csv
#   inflating: pt_290/ct.csv
#   inflating: pt_290/voxel_dimensions.csv
#   inflating: pt_290/PTV56.csv
#   inflating: pt_290/LeftParotid.csv
#   inflating: pt_290/SpinalCord.csv
#   inflating: pt_290/Brainstem.csv
#   inflating: pt_290/PTV70.csv
#   inflating: pt_290/Mandible.csv
#   inflating: pt_290/PTV63.csv
#   inflating: pt_264/possible_dose_mask.csv
#   inflating: pt_264/RightParotid.csv
#   inflating: pt_264/ct.csv
#   inflating: pt_264/voxel_dimensions.csv
#   inflating: pt_264/PTV56.csv
#   inflating: pt_264/LeftParotid.csv
#   inflating: pt_264/SpinalCord.csv
#   inflating: pt_264/Brainstem.csv
#   inflating: pt_264/PTV70.csv
#   inflating: pt_264/Mandible.csv
#   inflating: pt_264/PTV63.csv

# %%
# !rm "/content/testeo/.DS_Store"
# Out:
# rm: cannot remove '/content/testeo/.DS_Store': No such file or directory

# %% [markdown]
# ## Import libraries

# %%
# !sudo apt-get install libopenexr-dev
# !pip install --upgrade OpenEXR
# !sudo apt-get install libopenexr-dev
# !pip install --upgrade OpenEXR
# !pip install --upgrade tensorflow-graphics-gpu
# !pip install trimesh
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopenexr-dev is already the newest version (2.2.0-11.1ubuntu1.2).
# libopenexr-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Collecting OpenEXR
#   Downloading https://files.pythonhosted.org/packages/7c/c4/76bf884f59d3137847edf8b93aaf40f6257d8315d0064e8b1a606ad80b1b/OpenEXR-1.3.2.tar.gz
# Building wheels for collected packages: OpenEXR
#   Building wheel for OpenEXR (setup.py) ... done
#   Created wheel for OpenEXR: filename=OpenEXR-1.3.2-cp36-cp36m-linux_x86_64.whl size=188418 sha256=d5d74857f8bf84d69d10f7cdb29daf4ef39f7730ffa2cbd1aafe5b43bc3ddb53
#   Stored in directory: /root/.cache/pip/wheels/41/06/9f/c7dc838815b0e7dfc7d7dc19cc3d677edb47594d8489adc62a
# Successfully built OpenEXR
# Installing collected packages: OpenEXR
# Successfully installed OpenEXR-1.3.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopenexr-dev is already the newest version (2.2.0-11.1ubuntu1.2).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Requirement already up-to-date: OpenEXR in /usr/local/lib/python3.6/dist-packages (1.3.2)
# Collecting tensorflow-graphics-gpu
#   Downloading https://files.pythonhosted.org/packages/94/51/28fba58d7b6b7cd94a11176d6428fa7fd4813ba47755f7a85e32f9b6c240/tensorflow_graphics_gpu-1.0.0-py2.py3-none-any.whl (243kB)
#      |████████████████████████████████| 245kB 2.7MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow-graphics-gpu) (1.18.4)
# Requirement already satisfied, skipping upgrade: six>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-graphics-gpu) (1.12.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-graphics-gpu) (1.4.1)
# Collecting tensorflow-gpu>=1.13.1
#   Downloading https://files.pythonhosted.org/packages/31/bf/c28971266ca854a64f4b26f07c4112ddd61f30b4d1f18108b954a746f8ea/tensorflow_gpu-2.2.0-cp36-cp36m-manylinux2010_x86_64.whl (516.2MB)
#      |████████████████████████████████| 516.2MB 31kB/s
# Requirement already satisfied, skipping upgrade: absl-py>=0.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-graphics-gpu) (0.9.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.10.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.3.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.2.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.2.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.1.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.34.2)
# Requirement already satisfied, skipping upgrade: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.6.3)
# Requirement already satisfied, skipping upgrade: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.10.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.29.0)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.3.3)
# Requirement already satisfied, skipping upgrade: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.2.1)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.12.1)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.2.1)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.1.2)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (46.4.0)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.23.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.2.2)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.0.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.7.2)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.4.1)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.6.0.post3)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.9)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.6.0)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.2.8)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.3.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.1.0)
# Installing collected packages: tensorflow-gpu, tensorflow-graphics-gpu
# Successfully installed tensorflow-gpu-2.2.0 tensorflow-graphics-gpu-1.0.0
# Collecting trimesh
#   Downloading https://files.pythonhosted.org/packages/0a/dd/3de2fdc20173ededef4f3d3a5d20878daec924883edd4311ccb5886a34ca/trimesh-3.6.43-py3-none-any.whl (614kB)
#      |████████████████████████████████| 614kB 2.8MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from trimesh) (46.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from trimesh) (1.18.4)
# Installing collected packages: trimesh
# Successfully installed trimesh-3.6.43

# %%
# %tensorflow_version 2.x

# %%
import shutil
import json
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os 
import tensorflow as tf
from tensorflow.keras import *
from tensorflow.keras.layers import *
import trimesh
import tensorflow_graphics as tfg
from IPython.display import clear_output

# %% [markdown]
# ## Data loader and general functions

# %%
def create_hist(img):
  h = np.squeeze(img).flatten()*100
  return h

def create_out_file(in_url,out_url):
  dir_main = os.listdir(in_url)
  for patient in dir_main:
    os.mkdir(out_url + "/" + patient)

def create_random():
  random = np.zeros(13)
  random[0] = np.random.rand()
  random[1] = (np.random.rand()*1)-0.5
  random[2] = np.random.rand()
  random[3] = (np.random.rand()*1)-0.5
  random[4] = np.random.rand()
  random[5] = (np.random.rand()*1)-0.5
  random[6] = np.random.rand()
  random[7] = np.random.rand()
  random[8] = np.random.rand()
  random[9] = np.random.rand()
  random[10] = (np.random.rand()*0.2) + 0.9
  random[11] = (np.random.rand()*0.2) + 0.9
  random[12] = (np.random.rand()*0.2) + 0.9

  return random



### Variant functions for  RandomJiter ###

def unravel_ct_dose_indices(data_img,random):
  array = np.zeros((128,128,128))
  indices = tuple(map(tuple,np.unravel_index(tuple(data_img.index),(128,128,128),order="C")))
  values  = data_img.data.values
  indices,values = random_jitter(indices,values,random)
  array[indices] = values

  return array

def unravel_masks_indices(data_img,random):
  array = np.zeros((128,128,128))
  indices = tuple(map(tuple,np.unravel_index(tuple(data_img.index),(128,128,128),order="C")))
  values = np.ones(data_img.index.shape)
  indices,values = random_jitter(indices,values,random)
  array[indices] = 1

  return array


def random_jitter(indices,values,random):
  points = tf.cast(tf.transpose(tf.squeeze(tf.constant([indices]))),dtype=tf.float32)
  center = tf.constant([64,64,64],dtype = tf.float32)
  points_center = points - center
  #rotation type 1
  if random[0] < 0.1:
    #print("rotation type 1")
    axis = tf.constant([0,0,1],dtype=tf.float32) # Cartesians coordenates
    angle = tf.constant([random[1]],dtype=tf.float32)  # Radians Angles
    points_center = tfg.geometry.transformation.axis_angle.rotate(points_center,axis,angle)
  #rotation type 2 
  if random[2] < 0.1:
    #print("rotation type 2")
    axis = tf.constant([0,1,0],dtype=tf.float32) # Cartesians coordenates
    angle = tf.constant([random[3]],dtype=tf.float32)  # Radians Angles
    points_center = tfg.geometry.transformation.axis_angle.rotate(points_center,axis,angle) 
  #rotation type 3
  if random[4] < 0.1:
    #print("rotation type 3")
    axis = tf.constant([1,0,0],dtype=tf.float32) # Cartesians coordenates
    angle = tf.constant([random[5]],dtype=tf.float32)  # Radians Angles
    points_center = tfg.geometry.transformation.axis_angle.rotate(points_center,axis,angle) 
  #flip type 1
  if random[6] < 0.1:
    #print("flip type 1")
    flip = tf.constant([-1,1,1],dtype= tf.float32)
    points_center = points_center*flip
  #flip type 2
  if random[7] < 0.1:
    #print("flip type 2")
    flip = tf.constant([1,-1,1],dtype= tf.float32)
    points_center = points_center*flip
  #flip type 3
  if random[8] < 0.1:
    #print("flip type 3")
    flip = tf.constant([1,1,-1],dtype= tf.float32)
    points_center = points_center*flip
  # ReScale
  if random[9] < 0.1:
    #print("Reescale")
    scale = tf.constant([random[10],random[11],random[12]],dtype= tf.float32)
    points_center = points_center*scale

  points = points_center + center

  points = tf.cast(points,dtype=tf.int32)

  points = tf.where(points >= 128, 0, points)
  points = tf.where(points <= 0, 0, points)
  
  points = tf.where(points < 0, 0, points)

  values = values[~np.all(points == 0, axis=1)]
  points = points[~np.all(points == 0, axis=1)]

  points = tf.cast(tf.transpose(points),dtype=tf.int32)

  s = points.numpy()

  array_of_tuples = map(tuple, s)

  tuple_of_tuples = tuple(array_of_tuples)

  t_points = tuple_of_tuples

  return t_points, values

def decode_to_CT_Dose_jitter(url_element,random):
  array = pd.read_csv(url_element,index_col=0)
  array = np.expand_dims(np.expand_dims( unravel_ct_dose_indices(array,random),axis = 0),axis = 4)
  return array

def decode_unique_mask_jitter(url_element,random):
  array = pd.read_csv(url_element,index_col=0)
  array = np.expand_dims(np.expand_dims(unravel_masks_indices(array,random),axis = 0),axis = 4)
  return array


def decode_fusion_maks_jitter(link,list_name_masks,dict_num_mask,random):
  masks = np.zeros([1,128,128,128,10])
  organs_patien = os.listdir(link)
  for name in list_name_masks:
    if name + ".csv" in organs_patien:
      dir_mask = link + "/" + name + ".csv"
      array = pd.read_csv(dir_mask,index_col=0)
      array = unravel_masks_indices(array,random)
      masks[0,:,:,:,dict_num_mask[name]] = array

  return masks


def load_patient_train_jitter(dir_patient):
  random = create_random()
  dict_images = {"ct":None,"dose":None,"masks":None,"possible_dose_mask":None}
  ct = decode_to_CT_Dose_jitter(dir_patient + "/" + "ct.csv",random)
  dose = decode_to_CT_Dose_jitter(dir_patient + "/" + "dose.csv",random)
  possible_dose_mask = decode_unique_mask_jitter(dir_patient + "/" + "possible_dose_mask.csv",random)

  list_masks = ['Brainstem',
                'SpinalCord',
                'RightParotid',
                'LeftParotid',
                'Esophagus',
                'Larynx',
                'Mandible',
                'PTV56',
                'PTV63',
                'PTV70']
  dict_num_mask = {"Brainstem":0,
                    "SpinalCord":1,
                    "RightParotid":2,
                    "LeftParotid":3,
                    "Esophagus":4,
                    "Larynx":5,
                    "Mandible":6,
                    "PTV56":7,
                    "PTV63":8,
                    "PTV70":9}
  masks = decode_fusion_maks_jitter(dir_patient,list_masks,dict_num_mask,random)
  dict_images["ct"] = ct
  dict_images["dose"] = dose
  dict_images["masks"] = masks
  dict_images["possible_dose_mask"] = possible_dose_mask

  return dict_images


##########################################


def decode_to_CT_Dose_indices(url_element):
  array = pd.read_csv(url_element,index_col=0)
  indices,values = unravel_ct_dose_indices(array)
  return indices,values

def decode_unique_mask(url_element):
  array = pd.read_csv(url_element,index_col=0)
  indices = unravel_masks_indices(array)
  return indices


def unravel_ct_dose(data_img):
  array = np.zeros((128,128,128))
  indices = tuple(map(tuple,np.unravel_index(tuple(data_img.index),(128,128,128),order="C")))
  array[indices] = data_img.data.values
  return array

def unravel_masks(data_img):
  array = np.zeros((128,128,128))
  indices = tuple(map(tuple,np.unravel_index(tuple(data_img.index),(128,128,128),order="C")))
  array[indices] = 1
  return array
  

def decode_to_CT_Dose(url_element):
  array = pd.read_csv(url_element,index_col=0)
  array = np.expand_dims(np.expand_dims(unravel_ct_dose(array),axis = 0),axis = 4)
  return array

def decode_unique_mask(url_element):
  array = pd.read_csv(url_element,index_col=0)
  array = np.expand_dims(np.expand_dims(unravel_masks(array),axis = 0),axis = 4)
  return array

def decode_voxel_dimensions(url_element):
  array = np.loadtxt(url_element)
  return array

def decode_fusion_maks(link,list_name_masks,dict_num_mask):
  masks = np.zeros([1,128,128,128,10])
  organs_patien = os.listdir(link)
  for name in list_name_masks:
    if name + ".csv" in organs_patien:
      dir_mask = link + "/" + name + ".csv"
      array = pd.read_csv(dir_mask,index_col=0)
      array = unravel_masks(array)
      masks[0,:,:,:,dict_num_mask[name]] = array

  return masks
     

def get_patient_list(url_main):
  return os.listdir(url_main)


def load_patient_train(dir_patient):
  dict_images = {"ct":None,"dose":None,"masks":None}
  ct = decode_to_CT_Dose(dir_patient + "/" + "ct.csv")
  dose = decode_to_CT_Dose(dir_patient + "/" + "dose.csv")
  list_masks = ['Brainstem',
                'SpinalCord',
                'RightParotid',
                'LeftParotid',
                'Esophagus',
                'Larynx',
                'Mandible',
                'PTV56',
                'PTV63',
                'PTV70']
  dict_num_mask = {"Brainstem":0,
                    "SpinalCord":1,
                    "RightParotid":2,
                    "LeftParotid":3,
                    "Esophagus":4,
                    "Larynx":5,
                    "Mandible":6,
                    "PTV56":7,
                    "PTV63":8,
                    "PTV70":9}
  masks = decode_fusion_maks(dir_patient,list_masks,dict_num_mask)
  dict_images["ct"] = ct
  dict_images["dose"] = dose
  dict_images["masks"] = masks

  return dict_images


def load_patient(dir_patient):
  dict_images = {"ct":None,"dose":None,"possible_dose_mask":None,"voxel_dimensions":None,"masks":None}
  ct = decode_to_CT_Dose(dir_patient + "/" + "ct.csv")
  dose = decode_to_CT_Dose(dir_patient + "/" + "dose.csv")
  possible_dose_mask = decode_unique_mask(dir_patient + "/" + "possible_dose_mask.csv")
  voxel_dimensions = decode_voxel_dimensions(dir_patient + "/" + "voxel_dimensions.csv")
  list_masks = ['Brainstem',
                'SpinalCord',
                'RightParotid',
                'LeftParotid',
                'Esophagus',
                'Larynx',
                'Mandible',
                'PTV56',
                'PTV63',
                'PTV70']
  dict_num_mask = {"Brainstem":0,
                    "SpinalCord":1,
                    "RightParotid":2,
                    "LeftParotid":3,
                    "Esophagus":4,
                    "Larynx":5,
                    "Mandible":6,
                    "PTV56":7,
                    "PTV63":8,
                    "PTV70":9}
  masks = decode_fusion_maks(dir_patient,list_masks,dict_num_mask)
  dict_images["ct"] = ct
  dict_images["dose"] = dose
  dict_images["possible_dose_mask"] = possible_dose_mask
  dict_images["voxel_dimensions"] = voxel_dimensions
  dict_images["masks"] = masks

  return dict_images



def load_patient_test(dir_patient):
  dict_images = {"ct":None,"possible_dose_mask":None,"voxel_dimensions":None,"masks":None}
  ct = decode_to_CT_Dose(dir_patient + "/" + "ct.csv")
  possible_dose_mask = decode_unique_mask(dir_patient + "/" + "possible_dose_mask.csv")
  voxel_dimensions = decode_voxel_dimensions(dir_patient + "/" + "voxel_dimensions.csv")
  list_masks = ['Brainstem',
                'SpinalCord',
                'RightParotid',
                'LeftParotid',
                'Esophagus',
                'Larynx',
                'Mandible',
                'PTV56',
                'PTV63',
                'PTV70']
  dict_num_mask = {"Brainstem":0,
                    "SpinalCord":1,
                    "RightParotid":2,
                    "LeftParotid":3,
                    "Esophagus":4,
                    "Larynx":5,
                    "Mandible":6,
                    "PTV56":7,
                    "PTV63":8,
                    "PTV70":9}
  masks = decode_fusion_maks(dir_patient,list_masks,dict_num_mask)
  dict_images["ct"] = ct
  dict_images["possible_dose_mask"] = possible_dose_mask
  dict_images["voxel_dimensions"] = voxel_dimensions
  dict_images["masks"] = masks

  return dict_images

# %%
url_train = "/content/train-pats"
patients = get_patient_list(url_train)
for i,patient in enumerate(patients):
  patients[i] = os.path.join(url_train,patient)

# %%
np.random.seed(16)
np.random.shuffle(patients) 
X = patients
percent_train = 0.8
X_train = X[0:int(len(X)*percent_train)]
X_test = X[int(len(X)*percent_train):]

# %%
patients
# Out:
# ['/content/train-pats/pt_190',
#  '/content/train-pats/pt_3',
#  '/content/train-pats/pt_166',
#  '/content/train-pats/pt_110',
#  '/content/train-pats/pt_76',
#  '/content/train-pats/pt_99',
#  '/content/train-pats/pt_172',
#  '/content/train-pats/pt_69',
#  '/content/train-pats/pt_179',
#  '/content/train-pats/pt_67',
#  '/content/train-pats/pt_77',
#  '/content/train-pats/pt_157',
#  '/content/train-pats/pt_156',
#  '/content/train-pats/pt_70',
#  '/content/train-pats/pt_33',
#  '/content/train-pats/pt_14',
#  '/content/train-pats/pt_136',
#  '/content/train-pats/pt_57',
#  '/content/train-pats/pt_177',
#  '/content/train-pats/pt_98',
#  '/content/train-pats/pt_102',
#  '/content/train-pats/pt_31',
#  '/content/train-pats/pt_36',
#  '/content/train-pats/pt_44',
#  '/content/train-pats/pt_184',
#  '/content/train-pats/pt_72',
#  '/content/train-pats/pt_61',
#  '/content/train-pats/pt_8',
#  '/content/train-pats/pt_171',
#  '/content/train-pats/pt_66',
#  '/content/train-pats/pt_168',
#  '/content/train-pats/pt_84',
#  '/content/train-pats/pt_132',
#  '/content/train-pats/pt_131',
#  '/content/train-pats/pt_40',
#  '/content/train-pats/pt_181',
#  '/content/train-pats/pt_196',
#  '/content/train-pats/pt_149',
#  '/content/train-pats/pt_60',
#  '/content/train-pats/pt_11',
#  '/content/train-pats/pt_47',
#  '/content/train-pats/pt_170',
#  '/content/train-pats/pt_159',
#  '/content/train-pats/pt_91',
#  '/content/train-pats/pt_68',
#  '/content/train-pats/pt_90',
#  '/content/train-pats/pt_187',
#  '/content/train-pats/pt_100',
#  '/content/train-pats/pt_133',
#  '/content/train-pats/pt_75',
#  '/content/train-pats/pt_176',
#  '/content/train-pats/pt_183',
#  '/content/train-pats/pt_87',
#  '/content/train-pats/pt_103',
#  '/content/train-pats/pt_85',
#  '/content/train-pats/pt_7',
#  '/content/train-pats/pt_195',
#  '/content/train-pats/pt_39',
#  '/content/train-pats/pt_73',
#  '/content/train-pats/pt_22',
#  '/content/train-pats/pt_186',
#  '/content/train-pats/pt_147',
#  '/content/train-pats/pt_137',
#  '/content/train-pats/pt_46',
#  '/content/train-pats/pt_58',
#  '/content/train-pats/pt_192',
#  '/content/train-pats/pt_21',
#  '/content/train-pats/pt_78',
#  '/content/train-pats/pt_115',
#  '/content/train-pats/pt_167',
#  '/content/train-pats/pt_15',
#  '/content/train-pats/pt_200',
#  '/content/train-pats/pt_20',
#  '/content/train-pats/pt_89',
#  '/content/train-pats/pt_34',
#  '/content/train-pats/pt_142',
#  '/content/train-pats/pt_97',
#  '/content/train-pats/pt_118',
#  '/content/train-pats/pt_125',
#  '/content/train-pats/pt_1',
#  '/content/train-pats/pt_2',
#  '/content/train-pats/pt_191',
#  '/content/train-pats/pt_18',
#  '/content/train-pats/pt_24',
#  '/content/train-pats/pt_9',
#  '/content/train-pats/pt_127',
#  '/content/train-pats/pt_54',
#  '/content/train-pats/pt_189',
#  '/content/train-pats/pt_59',
#  '/content/train-pats/pt_63',
#  '/content/train-pats/pt_116',
#  '/content/train-pats/pt_45',
#  '/content/train-pats/pt_113',
#  '/content/train-pats/pt_182',
#  '/content/train-pats/pt_197',
#  '/content/train-pats/pt_82',
#  '/content/train-pats/pt_28',
#  '/content/train-pats/pt_199',
#  '/content/train-pats/pt_141',
#  '/content/train-pats/pt_121',
#  '/content/train-pats/pt_19',
#  '/content/train-pats/pt_27',
#  '/content/train-pats/pt_55',
#  '/content/train-pats/pt_101',
#  '/content/train-pats/pt_26',
#  '/content/train-pats/pt_42',
#  '/content/train-pats/pt_165',
#  '/content/train-pats/pt_79',
#  '/content/train-pats/pt_38',
#  '/content/train-pats/pt_12',
#  '/content/train-pats/pt_53',
#  '/content/train-pats/pt_17',
#  '/content/train-pats/pt_111',
#  '/content/train-pats/pt_83',
#  '/content/train-pats/pt_6',
#  '/content/train-pats/pt_64',
#  '/content/train-pats/pt_30',
#  '/content/train-pats/pt_32',
#  '/content/train-pats/pt_173',
#  '/content/train-pats/pt_138',
#  '/content/train-pats/pt_56',
#  '/content/train-pats/pt_126',
#  '/content/train-pats/pt_194',
#  '/content/train-pats/pt_74',
#  '/content/train-pats/pt_4',
#  '/content/train-pats/pt_117',
#  '/content/train-pats/pt_10',
#  '/content/train-pats/pt_80',
#  '/content/train-pats/pt_62',
#  '/content/train-pats/pt_49',
#  '/content/train-pats/pt_92',
#  '/content/train-pats/pt_123',
#  '/content/train-pats/pt_13',
#  '/content/train-pats/pt_145',
#  '/content/train-pats/pt_37',
#  '/content/train-pats/pt_155',
#  '/content/train-pats/pt_122',
#  '/content/train-pats/pt_139',
#  '/content/train-pats/pt_162',
#  '/content/train-pats/pt_43',
#  '/content/train-pats/pt_130',
#  '/content/train-pats/pt_128',
#  '/content/train-pats/pt_198',
#  '/content/train-pats/pt_114',
#  '/content/train-pats/pt_160',
#  '/content/train-pats/pt_119',
#  '/content/train-pats/pt_188',
#  '/content/train-pats/pt_161',
#  '/content/train-pats/pt_164',
#  '/content/train-pats/pt_48',
#  '/content/train-pats/pt_71',
#  '/content/train-pats/pt_144',
#  '/content/train-pats/pt_23',
#  '/content/train-pats/pt_178',
#  '/content/train-pats/pt_93',
#  '/content/train-pats/pt_95',
#  '/content/train-pats/pt_5',
#  '/content/train-pats/pt_146',
#  '/content/train-pats/pt_107',
#  '/content/train-pats/pt_35',
#  '/content/train-pats/pt_135',
#  '/content/train-pats/pt_94',
#  '/content/train-pats/pt_108',
#  '/content/train-pats/pt_134',
#  '/content/train-pats/pt_96',
#  '/content/train-pats/pt_163',
#  '/content/train-pats/pt_151',
#  '/content/train-pats/pt_109',
#  '/content/train-pats/pt_112',
#  '/content/train-pats/pt_120',
#  '/content/train-pats/pt_104',
#  '/content/train-pats/pt_148',
#  '/content/train-pats/pt_86',
#  '/content/train-pats/pt_50',
#  '/content/train-pats/pt_52',
#  '/content/train-pats/pt_154',
#  '/content/train-pats/pt_174',
#  '/content/train-pats/pt_158',
#  '/content/train-pats/pt_193',
#  '/content/train-pats/pt_152',
#  '/content/train-pats/pt_16',
#  '/content/train-pats/pt_175',
#  '/content/train-pats/pt_106',
#  '/content/train-pats/pt_150',
#  '/content/train-pats/pt_129',
#  '/content/train-pats/pt_41',
#  '/content/train-pats/pt_153',
#  '/content/train-pats/pt_143',
#  '/content/train-pats/pt_180',
#  '/content/train-pats/pt_140',
#  '/content/train-pats/pt_29',
#  '/content/train-pats/pt_124',
#  '/content/train-pats/pt_65',
#  '/content/train-pats/pt_51',
#  '/content/train-pats/pt_88',
#  '/content/train-pats/pt_25',
#  '/content/train-pats/pt_81',
#  '/content/train-pats/pt_185',
#  '/content/train-pats/pt_169',
#  '/content/train-pats/pt_105']

# %%
def load_images_to_net_jitter(patient_url):

  images = load_patient_train_jitter(patient_url)

  ct = tf.cast(np.where(images["ct"] <= 4500,images["ct"],0),dtype=tf.float32)
  ct = (2*ct/4500) - 1
  masks = tf.cast(images["masks"],dtype=tf.float32)
  dose = tf.cast(np.where(images["dose"] <= 100,images["dose"],0),dtype=tf.float32)
  dose = (2*dose/100) - 1

  possible_dose_mask = tf.cast(images["possible_dose_mask"],dtype=tf.float32)
  
  return ct,masks,dose,possible_dose_mask

# %%
def load_images_to_net(patient_url):

  images = load_patient_train(patient_url)

  ct = tf.cast(np.where(images["ct"] <= 4500,images["ct"],0),dtype=tf.float32)
  ct = (2*ct/4500) - 1
  masks = tf.cast(images["masks"],dtype=tf.float32)
  dose = tf.cast(np.where(images["dose"] <= 100,images["dose"],0),dtype=tf.float32)
  dose = (2*dose/100) - 1
  
  return ct,masks,dose

def load_images_to_net_test(patient_url):

  images = load_patient_test(patient_url)

  ct = ct = tf.cast(np.where(images["ct"] <= 4500,images["ct"],0),dtype=tf.float32)
  ct = (2*ct/4500) - 1
  masks = tf.cast(images["masks"],dtype=tf.float32)
  possible_dose_mask = tf.cast(images["possible_dose_mask"],dtype=tf.float32)
  voxel_dimensions = tf.cast(images["voxel_dimensions"],dtype=tf.float32)

  
  return ct,masks,possible_dose_mask,voxel_dimensions

# %% [markdown]
# ## Architecture

# %% [markdown]
# ![texto alternativo](https://paper-attachments.dropbox.com/s_84D9D849F786EC83B26BF2A0F74F0C33230682E8BA1D41AD8C3F3D770D23236A_1566175741579_dlhacks-perceptual-adversarial-networks-for-imagetoimage-transformation-7-638.jpg)
# https://blog.paperspace.com/unpaired-image-to-image-translation-with-cyclegan/

# %% [markdown]
# ### Create downsample and upsample functions

# %%
def downsample(filters, apply_batchnorm=True):

  result = Sequential() 

  initializer = tf.random_normal_initializer(0,0.02)

  #capa convolucional 

  result.add(Conv3D(filters,
                    kernel_size = 4,
                    strides = 2,
                    padding = "same",
                    kernel_initializer = initializer,
                    use_bias = not apply_batchnorm))

  # Capa de batch normalization 

  if apply_batchnorm:
    result.add(BatchNormalization())

  #Capa de activacion (leak relu)

  result.add(ReLU()) 

  return result

# %%
def upsample(filters, apply_dropout=False):

  result = Sequential() 

  initializer = tf.random_normal_initializer(0,0.02)

  #capa convolucional 

  result.add(Conv3DTranspose(filters,
                             kernel_size = 4,
                             strides = 2,
                             padding = "same",
                             kernel_initializer = initializer,
                             use_bias = False))

  # Capa de batch normalization 
  result.add(BatchNormalization())

  if apply_dropout:
    result.add(Dropout(0.5))
    

  #Capa de activacion (leak relu)
  result.add(ReLU()) 

  return result

# %% [markdown]
# ### Create generator-net

# %%
def Generator():
  ct_image = Input(shape=[128,128,128,1])
  roi_masks = Input(shape=[128,128,128,10])

  inputs = concatenate([ct_image, roi_masks])

  down_stack = [
    downsample(64, apply_batchnorm=False), # (64x64x64x64)
    downsample(128),  #32  (32x32x32x128)
    downsample(256),  #16  (16x16x16x16x256) 
    downsample(512),  #8   (8x8x8x512)
    downsample(512),  #4   (4x4x4x512)
    downsample(512),  #2   (2x2x2x512)
    downsample(512),  #1  (1x1x1x512)
  ]

  up_stack = [ 
    upsample(512,apply_dropout=True), #2 (2x2x2x512)
    upsample(512,apply_dropout=True), #4 (4x4x4x512)
    upsample(512),  #8  (8x8x8x512)
    upsample(256),  #16  (16x16x16x256)
    upsample(128),  #32  (32x32x32x128)
    upsample(64),   #64  (64x64x64x64)
  ]

  initializer = tf.random_normal_initializer(0,0.02)

  last = Conv3DTranspose(filters=1,
                         kernel_size = 4,
                         strides = 2,
                         padding = "same",
                         kernel_initializer = initializer,
                         activation = "tanh")                     #(128x128x128x3)
  

  x = inputs

  s = []

  concat = Concatenate()

  for down in down_stack:
    x = down(x)
    s.append(x)

  s = reversed(s[:-1])

  for up,sk in zip(up_stack,s):
    x = up(x)
    x = concat([x,sk])

  last = last(x)

  return Model(inputs = [ct_image,roi_masks], outputs = last)

generator = Generator()

# %% [markdown]
# ### Run generator-net

# %%
ct,masks,dose,possible_dose_mask = load_images_to_net_jitter("/content/train-pats/pt_150")
gen_output = generator([ct,masks],training=True)


c = (ct[0,:,:,88,0]+1)/2
d = (dose[0,:,:,88,0]+1)/2
p = (gen_output[0,:,:,88,0]+1)/2

fig=plt.figure(figsize=(16, 16))
fig.add_subplot(3,3,1)
plt.title("ct")
plt.imshow(c)
fig.add_subplot(3,3,2)
plt.title("dose")
plt.imshow(d)
fig.add_subplot(3,3,3)
plt.title("predict")
plt.imshow(p)

fig.add_subplot(3,3,4)
plt.hist(create_hist(c),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,5)
plt.hist(create_hist(d),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,6)
plt.hist(create_hist(p),  bins=100,range=[1,100])
plt.ylabel('Probability')

fig.add_subplot(3,3,7)
plt.hist(create_hist((ct+1)/2), bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,8)
plt.hist(create_hist((dose+1)/2),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,9)
plt.hist(create_hist((gen_output+1)/2),  bins=100,range=[1,100])
plt.ylabel('Probability')


plt.show()

# %%
ct,masks,dose,possible_dose_mask = load_images_to_net_jitter(X_test[18])
gen_output = generator([ct,masks],training=True)


c = (ct[0,:,:,88,0]+1)/2
d = (dose[0,:,:,88,0]+1)/2
p = (gen_output[0,:,:,88,0]+1)/2

fig=plt.figure(figsize=(16, 16))
fig.add_subplot(3,3,1)
plt.title("ct")
plt.imshow(c)
fig.add_subplot(3,3,2)
plt.title("dose")
plt.imshow(d)
fig.add_subplot(3,3,3)
plt.title("predict")
plt.imshow(p)

fig.add_subplot(3,3,4)
plt.hist(create_hist(c),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,5)
plt.hist(create_hist(d),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,6)
plt.hist(create_hist(p),  bins=100,range=[1,100])
plt.ylabel('Probability')

fig.add_subplot(3,3,7)
plt.hist(create_hist((ct+1)/2), bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,8)
plt.hist(create_hist((dose+1)/2),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,9)
plt.hist(create_hist((gen_output+1)/2),  bins=100,range=[1,100])
plt.ylabel('Probability')


plt.show()

# %%
ct,masks,dose = load_images_to_net(X_test[10])
gen_output = generator([ct,masks],training=True)


c = (ct[0,:,:,70,0]+1)/2
d = (dose[0,:,:,70,0]+1)/2
p = (gen_output[0,:,:,70,0]+1)/2

fig=plt.figure(figsize=(16, 16))
fig.add_subplot(3,3,1)
plt.title("ct")
plt.imshow(c)
fig.add_subplot(3,3,2)
plt.title("dose")
plt.imshow(d)
fig.add_subplot(3,3,3)
plt.title("predict")
plt.imshow(p)

fig.add_subplot(3,3,4)
plt.hist(create_hist(c),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,5)
plt.hist(create_hist(d),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,6)
plt.hist(create_hist(p),  bins=100,range=[1,100])
plt.ylabel('Probability')

fig.add_subplot(3,3,7)
plt.hist(create_hist((ct+1)/2), bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,8)
plt.hist(create_hist((dose+1)/2),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,9)
plt.hist(create_hist((gen_output+1)/2),  bins=100,range=[1,100])
plt.ylabel('Probability')


plt.show()

# %%
ct,masks,dose,possible_dose_mask = load_images_to_net_jitter(X_test[10])
gen_output = generator([ct,masks],training=True)


c = (ct[0,:,:,75,0]+1)/2
d = (dose[0,:,:,75,0]+1)/2
p = (gen_output[0,:,:,75,0]+1)/2

fig=plt.figure(figsize=(16, 16))
fig.add_subplot(3,3,1)
plt.title("ct")
plt.imshow(c)
fig.add_subplot(3,3,2)
plt.title("dose")
plt.imshow(d)
fig.add_subplot(3,3,3)
plt.title("predict")
plt.imshow(p)

fig.add_subplot(3,3,4)
plt.hist(create_hist(c),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,5)
plt.hist(create_hist(d),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,6)
plt.hist(create_hist(p),  bins=100,range=[1,100])
plt.ylabel('Probability')

fig.add_subplot(3,3,7)
plt.hist(create_hist((ct+1)/2), bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,8)
plt.hist(create_hist((dose+1)/2),  bins=100,range=[1,100])
plt.ylabel('Probability')
fig.add_subplot(3,3,9)
plt.hist(create_hist((gen_output+1)/2),  bins=100,range=[1,100])
plt.ylabel('Probability')


plt.show()

# %% [markdown]
# ### Create discriminator-net

# %%
def Discriminator():
  ct_dis = Input(shape=[128,128,128,1], name = "ct_dis")
  ct_masks = Input(shape=[128,128,128,10], name = "ct_masks")
  dose_gen = Input(shape=[128,128,128,1], name = "dose_gen")

  con = concatenate([ct_dis,ct_masks,dose_gen])
  initializer = tf.random_normal_initializer(0,0.02)

  down1 = downsample(64, apply_batchnorm = False)(con)
  down2 = downsample(128)(down1)
  down3 = downsample(256)(down2)
 
    
  last = tf.keras.layers.Conv3D(filters = 1,
                           kernel_size = 4,
                           strides = 1,
                           kernel_initializer = initializer,
                           padding = "same")(down3)

  return tf.keras.Model(inputs = [ct_dis,ct_masks,dose_gen],outputs = last)


discriminator = Discriminator()

# %% [markdown]
# ### Run discriminator-net

# %%
disc_out = discriminator([ct,masks,gen_output],training = True)

w=16
h=16

# %%
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 4
for i in range(0, columns*rows):
    fig.add_subplot(rows, columns, i +1)
    plt.imshow(disc_out[0,:,:,i,0],vmin=-1,vmax=1,cmap = "RdBu_r")
    plt.colorbar()

plt.show()

# %%
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 4
for i in range(0, columns*rows):
    fig.add_subplot(rows, columns, i +1)
    plt.imshow(disc_out[0,:,i,:,0],vmin=-1,vmax=1,cmap = "RdBu_r")
    plt.colorbar()

plt.show()

# %%
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 4
for i in range(0, columns*rows):
    fig.add_subplot(rows, columns, i +1)
    plt.imshow(disc_out[0,i,:,:,0],vmin=-1,vmax=1,cmap = "RdBu_r")
    plt.colorbar()

plt.show()

# %% [markdown]
# ### Loss functions

# %%
# Funciones de coste adversarias 


loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)


def discriminator_loss(disc_real_output,disc_generated_output):

  #Diferencia entre los true por ser real y el detectado por el discriminador

  real_loss = loss_object(tf.ones_like(disc_real_output),disc_real_output)

  #Diferencia entre los false por ser generado y el detectado por el discriminador

  generated_loss = loss_object(tf.zeros_like(disc_generated_output),disc_generated_output)

  total_dics_loss = real_loss + generated_loss

  return total_dics_loss

# %%
LAMBDA = 100

def generator_loss(disc_generated_output,gen_output,target):

  gen_loss = loss_object(tf.ones_like(disc_generated_output),disc_generated_output)

  #mean absolute error

  l1_loss = tf.reduce_mean(tf.abs(target-gen_output))
  total_gen_loss = gen_loss + (LAMBDA*l1_loss)
  return total_gen_loss

# %% [markdown]
# ### Configure checkpoint

# %%
import os 

generator_optimizer = tf.keras.optimizers.Adam(2e-4,beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4,beta_1=0.5)

cpath = "/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/checkpointjitter3" #dir to checkpoints


checkpoint = tf.train.Checkpoint(generator_optimizer = generator_optimizer,
                                 discriminator_optimizer = discriminator_optimizer,
                                 generator = generator,
                                 discriminator = discriminator)

# %%
import os 

generator_optimizer = tf.keras.optimizers.Adam(2e-4,beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4,beta_1=0.5)

cpath = "/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/checkpointjose" #dir to checkpoints


checkpoint = tf.train.Checkpoint(generator_optimizer = generator_optimizer,
                                 discriminator_optimizer = discriminator_optimizer,
                                 generator = generator,
                                 discriminator = discriminator)

# %% [markdown]
# ## Train

# %% [markdown]
# ### Train step

# %%
@tf.function

def train_step(ct,masks,dose):

  with tf.GradientTape() as gen_tape, tf.GradientTape() as discr_tape:


    output_image = generator([ct,masks], training=True)

    output_gen_discr = discriminator([ct,masks,gen_output],training = True)

    output_trg_discr = discriminator([ct,masks,dose], training = True)

    discr_loss = discriminator_loss(output_trg_discr,output_gen_discr)

    #dose_loss = tf.reduce_sum(tf.abs((dose - (output_image*possible_dose_mask))))/tf.reduce_sum((possible_dose_mask))

    gen_loss = generator_loss(output_gen_discr,output_image,dose)

    #gen_loss = dose_loss*100 + gen_loss

    generator_grads = gen_tape.gradient(gen_loss, generator.trainable_variables)

    discriminator_grads = discr_tape.gradient(discr_loss,discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(generator_grads,generator.trainable_variables))

    discriminator_optimizer.apply_gradients(zip(discriminator_grads,discriminator.trainable_variables))

  return gen_loss

# %%
@tf.function
def test_step(ct,masks,dose,possible_dose_mask):
  output_image = generator([ct,masks], training=True)
  dose_loss = tf.reduce_sum(tf.abs((dose - (output_image*possible_dose_mask))))/tf.reduce_sum((possible_dose_mask))

# %% [markdown]
# ### Restore metrics

# %% [markdown]
# ### Define train-loop

# %%
train_dose_loss = []

# %%
test_dose_loss = []

# %%
def train(epochs):

  check = os.listdir(cpath)
  if len(check) > 0:
    if "state.txt" in check:
      start = int(np.loadtxt(cpath + "/state.txt"))
      print("upload checkpoint model")
      checkpoint.restore(tf.train.latest_checkpoint(cpath+"/"+str(start)))
  else: 
    start = 0
  
  

  print("Start training in epoch",start)

  for epoch in range(start,epochs):

    epoch_loss_dose_train = tf.keras.metrics.Mean()
    epoch_loss_dose_test = tf.keras.metrics.Mean()

    np.random.shuffle(patients) 
    imgi = 0
    for patient in patients:
      ct,masks,dose = load_images_to_net(patient)
      print("epoch " + str(epoch) + " - train: " + str(imgi) + "/" + str(len(X_train)))
      
      output_image = train_step(ct,masks,dose)


      #epoch_loss_dose_train(dose_loss)

      clear_output(wait=True)
      imgi += 1

      

    imgi = 0
    # saving (checkpoint) the model every 20 epochs
    if (epoch + 1) % 20 == 0:
      state = np.array([epoch+1])
      np.savetxt(cpath + "/state.txt",state)
      os.mkdir(cpath+"/"+str(epoch+1))
      checkpoint_prefix = os.path.join(cpath+"/"+str(epoch+1),"ckpt")
      checkpoint.save(file_prefix = checkpoint_prefix)
"""
    train_dose_loss.append(epoch_loss_dose_train.result())

    for patient in X_test:
      ct,masks,dose,possible_dose_mask = load_images_to_net_jitter(patient)
      dose_loss = test_step(ct,masks,dose,possible_dose_mask)
      epoch_loss_dose_test(dose_loss)
    
    #test_dose_loss.append(epoch_loss_dose_test.result())






    fig, axes = plt.subplots(2, sharex=True, figsize=(12, 8))
    fig.suptitle('Metrics')

    axes[0].set_ylabel("dose Loss train", fontsize=14)
    axes[0].plot(train_dose_loss)

    axes[1].set_ylabel("dose loss test", fontsize=14)
    axes[1].set_xlabel("Epoch", fontsize=14)
    axes[1].plot(test_dose_loss)
    plt.show()
"""
# Out:
# '\n    train_dose_loss.append(epoch_loss_dose_train.result())\n\n    for patient in X_test:\n      ct,masks,dose,possible_dose_mask = load_images_to_net_jitter(patient)\n      dose_loss = test_step(ct,masks,dose,possible_dose_mask)\n      epoch_loss_dose_test(dose_loss)\n    \n    #test_dose_loss.append(epoch_loss_dose_test.result())\n\n\n\n\n\n\n    fig, axes = plt.subplots(2, sharex=True, figsize=(12, 8))\n    fig.suptitle(\'Metrics\')\n\n    axes[0].set_ylabel("dose Loss train", fontsize=14)\n    axes[0].plot(train_dose_loss)\n\n    axes[1].set_ylabel("dose loss test", fontsize=14)\n    axes[1].set_xlabel("Epoch", fontsize=14)\n    axes[1].plot(test_dose_loss)\n    plt.show()\n'

# %% [markdown]
# ### Initialize train for epochs

# %%
train(220)
# Out:
# upload checkpoint model
# Start training in epoch 220

# %%
test_dose_loss
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=18.205654>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=18.35102>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=18.465977>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=18.371708>]

# %%
fig, axes = plt.subplots(2, sharex=True, figsize=(12, 8))
fig.suptitle('Metrics')

axes[0].set_ylabel("dose Loss", fontsize=14)
axes[0].plot(train_dose_loss)

axes[1].set_ylabel("dose loss", fontsize=14)
axes[1].set_xlabel("Epoch", fontsize=14)
axes[1].plot(test_dose_loss)
plt.show()

# %% [markdown]
# ## Evaluate

# %% [markdown]
# ### Restore model

# %%
cpath = "/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/checkpoint/220"

# %%
checkpoint.restore(tf.train.latest_checkpoint("/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/checkpoint/220"))

# %%
def upload_model():  
  check = os.listdir(cpath)
  if len(cpath) > 0:
    if "state.txt" in check:
      start = int(np.loadtxt(cpath + "/state.txt"))
    print("upload checkpoint model")
    checkpoint.restore(tf.train.latest_checkpoint(cpath+"/"+str(start)))
    
upload_model()
# Out:
# upload checkpoint model
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-60-6572c11e9d2a> in <module>()
#       7     checkpoint.restore(tf.train.latest_checkpoint(cpath+"/"+str(start)))
#       8
# ----> 9 upload_model()
#
# <ipython-input-60-6572c11e9d2a> in upload_model()
#       5       start = int(np.loadtxt(cpath + "/state.txt"))
#       6     print("upload checkpoint model")
# ----> 7     checkpoint.restore(tf.train.latest_checkpoint(cpath+"/"+str(start)))
#       8
#       9 upload_model()
#
# UnboundLocalError: local variable 'start' referenced before assignment

# %%
checkpoint.restore(tf.train.latest_checkpoint("/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/checkpoint/220"))

# %% [markdown]
# ### Loader patient to evaluate

# %%
ct,masks,possible_dose_mask,voxel_dimensions = load_images_to_net_test("/content/testeo/pt_270")
gen_output = generator([ct,masks],training=False)
gen_mask  = ((gen_output+1)/2)*possible_dose_mask

# %%
plt.imshow(gen_mask[0,:,:,80,0])

# %%
plt.imshow(ct[0,:,:,80,0])

# %%
plt.imshow((ct[0,:,:,75,0]+1)/2)

# %%
plt.imshow((gen_output[0,:,:,75,0]+1)/2)

# %%
w = np.squeeze(gen_mask ).flatten()*100
plt.hist(w,  bins=100,range=[1,100])
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
x = (gen_output[0,:,:,:,0]+1)/2
y = masks[0,:,:,:,8]
z = x * y

# %%
w = np.squeeze(z).flatten()*100
plt.hist(w, bins=100,range=[50,100])
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# ## Export doses predictions

# %%
@tf.function
def predict_step(ct,masks):
  output_image = generator([ct,masks], training=True)
  return output_image

# %%
url_main_results = "/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/export/results/resutls_v7"
url_main_validation = "/content/validation-pats-no-dose"

def export_csv(predict_dose,patient):
  dictionary = {"data":np.ravel(predict_dose,order="C")}
  array = pd.DataFrame(dictionary)
  array = array[array["data"] != 0]
  array.to_csv(url_main_results + "/" + patient + ".csv")


def validation():
  patients  = get_patient_list(url_main_validation)
  os.mkdir(url_main_results)
  inimg = 0
  for patient in patients:
    ct,masks,possible_dose_mask,voxel_dimensions = load_images_to_net_test(url_main_validation + "/" + patient)
    output_image = predict_step(ct,masks)
    #output_image = generator([ct,masks], training=True)
    predict_dose = np.squeeze((((output_image+1)/2)*possible_dose_mask)*100)
    export_csv(predict_dose,patient)
    print(" - predict: " + str(inimg) + "/" + str(len(patients)))
    inimg = inimg + 1

# %% [markdown]
# **Imagenes de testeo**

# %%
url_main_results = "/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/export/Test/v1"
url_main_validation = "/content/testeo"

def export_csv(predict_dose,patient):
  dictionary = {"data":np.ravel(predict_dose,order="C")}
  array = pd.DataFrame(dictionary)
  array = array[array["data"] != 0]
  array.to_csv(url_main_results + "/" + patient + ".csv")


def validation():
  patients  = get_patient_list(url_main_validation)
  os.mkdir(url_main_results)
  inimg = 0
  for patient in patients:
    ct,masks,possible_dose_mask,voxel_dimensions = load_images_to_net_test(url_main_validation + "/" + patient)
    output_image = predict_step(ct,masks)
    #output_image = generator([ct,masks], training=True)
    predict_dose = np.squeeze((((output_image+1)/2)*possible_dose_mask)*100)
    export_csv(predict_dose,patient)
    print(" - predict: " + str(inimg) + "/" + str(len(patients)))
    inimg = inimg + 1

# %%
validation()
# Out:
#  - predict: 0/100
#  - predict: 1/100
#  - predict: 2/100
#  - predict: 3/100
#  - predict: 4/100
#  - predict: 5/100
#  - predict: 6/100
#  - predict: 7/100
#  - predict: 8/100
#  - predict: 9/100
#  - predict: 10/100
#  - predict: 11/100
#  - predict: 12/100
#  - predict: 13/100
#  - predict: 14/100
#  - predict: 15/100
#  - predict: 16/100
#  - predict: 17/100
#  - predict: 18/100
#  - predict: 19/100
#  - predict: 20/100
#  - predict: 21/100
#  - predict: 22/100
#  - predict: 23/100
#  - predict: 24/100
#  - predict: 25/100
#  - predict: 26/100
#  - predict: 27/100
#  - predict: 28/100
#  - predict: 29/100
#  - predict: 30/100
#  - predict: 31/100
#  - predict: 32/100
#  - predict: 33/100
#  - predict: 34/100
#  - predict: 35/100
#  - predict: 36/100
#  - predict: 37/100
#  - predict: 38/100
#  - predict: 39/100
#  - predict: 40/100
#  - predict: 41/100
#  - predict: 42/100
#  - predict: 43/100
#  - predict: 44/100
#  - predict: 45/100
#  - predict: 46/100
#  - predict: 47/100
#  - predict: 48/100
#  - predict: 49/100
#  - predict: 50/100
#  - predict: 51/100
#  - predict: 52/100
#  - predict: 53/100
#  - predict: 54/100
#  - predict: 55/100
#  - predict: 56/100
#  - predict: 57/100
#  - predict: 58/100
#  - predict: 59/100
#  - predict: 60/100
#  - predict: 61/100
#  - predict: 62/100
#  - predict: 63/100
#  - predict: 64/100
#  - predict: 65/100
#  - predict: 66/100
#  - predict: 67/100
#  - predict: 68/100
#  - predict: 69/100
#  - predict: 70/100
#  - predict: 71/100
#  - predict: 72/100
#  - predict: 73/100
#  - predict: 74/100
#  - predict: 75/100
#  - predict: 76/100
#  - predict: 77/100
#  - predict: 78/100
#  - predict: 79/100
#  - predict: 80/100
#  - predict: 81/100
#  - predict: 82/100
#  - predict: 83/100
#  - predict: 84/100
#  - predict: 85/100
#  - predict: 86/100
#  - predict: 87/100
#  - predict: 88/100
#  - predict: 89/100
#  - predict: 90/100
#  - predict: 91/100
#  - predict: 92/100
#  - predict: 93/100
#  - predict: 94/100
#  - predict: 95/100
#  - predict: 96/100
#  - predict: 97/100
#  - predict: 98/100
#  - predict: 99/100

# %%
rm -r /content/testeo/.ipynb_checkpoints/

# %%
shutil.make_archive('/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/export/Test/submisions_v1/test', 'zip','/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/export/Test/v1')
# Out:
# '/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/export/Test/submisions_v1/test.zip'

# %%
x = decode_to_CT_Dose("/content/drive/My Drive/PAE_PYTHONQUANTIC/IA/OpenKBP/Auxiliary/results_v1/pt_204.csv")

# %%
plt.imshow(x[0,:,:,75,0])

# %% [markdown]
# ## Random jitter

# %%
# !sudo apt-get install libopenexr-dev
# !pip install --upgrade OpenEXR
# !sudo apt-get install libopenexr-dev
# !pip install --upgrade OpenEXR
# !pip install --upgrade tensorflow-graphics-gpu
# !pip install trimesh
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopenexr-dev is already the newest version (2.2.0-11.1ubuntu1.1).
# libopenexr-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Collecting OpenEXR
#   Downloading https://files.pythonhosted.org/packages/7c/c4/76bf884f59d3137847edf8b93aaf40f6257d8315d0064e8b1a606ad80b1b/OpenEXR-1.3.2.tar.gz
# Building wheels for collected packages: OpenEXR
#   Building wheel for OpenEXR (setup.py) ... done
#   Created wheel for OpenEXR: filename=OpenEXR-1.3.2-cp36-cp36m-linux_x86_64.whl size=188432 sha256=e631ca26b6240bbeaf81968b2a0a08282b6b74674c2c0e6050919b5e47ae9ca5
#   Stored in directory: /root/.cache/pip/wheels/41/06/9f/c7dc838815b0e7dfc7d7dc19cc3d677edb47594d8489adc62a
# Successfully built OpenEXR
# Installing collected packages: OpenEXR
# Successfully installed OpenEXR-1.3.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopenexr-dev is already the newest version (2.2.0-11.1ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Requirement already up-to-date: OpenEXR in /usr/local/lib/python3.6/dist-packages (1.3.2)
# Collecting tensorflow-graphics-gpu
#   Downloading https://files.pythonhosted.org/packages/94/51/28fba58d7b6b7cd94a11176d6428fa7fd4813ba47755f7a85e32f9b6c240/tensorflow_graphics_gpu-1.0.0-py2.py3-none-any.whl (243kB)
#      |████████████████████████████████| 245kB 9.8MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow-graphics-gpu) (1.18.2)
# Requirement already satisfied, skipping upgrade: six>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-graphics-gpu) (1.12.0)
# Collecting tensorflow-gpu>=1.13.1
#   Downloading https://files.pythonhosted.org/packages/0a/93/c7bca39b23aae45cd2e85ad3871c81eccc63b9c5276e926511e2e5b0879d/tensorflow_gpu-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8MB)
#      |████████████████████████████████| 421.8MB 39kB/s
# Requirement already satisfied, skipping upgrade: absl-py>=0.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-graphics-gpu) (0.9.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-graphics-gpu) (1.4.1)
# Requirement already satisfied, skipping upgrade: tensorboard<2.2.0,>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.1.1)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.12.1)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.8.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.0.8)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.2.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.1.0)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.2.0)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 42.3MB/s
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.27.2)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.34.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.10.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.1.0)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.7.2)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.21.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.2.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.4.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.0.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (46.0.0)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.10.0)
# Requirement already satisfied, skipping upgrade: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (4.0)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.24.3)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu>=1.13.1->tensorflow-graphics-gpu) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=ba1981fac1e4e4c75402edb29f5be2bdf4782e3649a0320543f06a48a2d755b2
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0rc1 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0rc1 has requirement tensorflow-estimator<2.3.0,>=2.2.0rc0, but you'll have tensorflow-estimator 2.1.0 which is incompatible.
# Installing collected packages: tensorflow-estimator, gast, tensorflow-gpu, tensorflow-graphics-gpu
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# Successfully installed gast-0.2.2 tensorflow-estimator-2.1.0 tensorflow-gpu-2.1.0 tensorflow-graphics-gpu-1.0.0
# Collecting trimesh
#   Downloading https://files.pythonhosted.org/packages/ca/6e/08456280f7c6631f835dc8eee0ac7d2cfc2300dd86753e8e4f20cab4d400/trimesh-3.6.18-py3-none-any.whl (456kB)
#      |████████████████████████████████| 460kB 9.3MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from trimesh) (1.18.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from trimesh) (46.0.0)
# Installing collected packages: trimesh
# Successfully installed trimesh-3.6.18

# %%
# %tensorflow_version 2.x

# %%
import numpy as np
import tensorflow as tf
import trimesh
import tensorflow_graphics as tfg
import numpy as np
import pandas as pd

# %%
def load_train_jitter(patient):

# %%
img = pd.read_csv("/content/train-pats/pt_1/ct.csv",index_col=0)

# %%
indices = tuple(map(tuple,np.unravel_index(tuple(img.index),(128,128,128),order="C")))

# %%
img.data.values[~np.all(w == 0, axis=1)]
# Out:
# array([ 6., 88.,  1., ...,  6., 30., 17.])

# %%
img.index.shape
# Out:
# (81257,)

# %%
print(indices)
# Out:
# ((32, 32, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37 ...

# %%
np.shape(indices)
# Out:
# (3, 81257)

# %%
print(indices[0][0])
print(indices[1][0])
print(indices[2][0])
# Out:
# 32
# 62
# 37

# %%
y = tf.constant([64,64,64],dtype = tf.float32)

# %%
x = tf.cast(tf.transpose(tf.squeeze(tf.constant([indices]))),dtype=tf.float32)

# %%
x
# Out:
# <tf.Tensor: shape=(81257, 3), dtype=float32, numpy=
# array([[32., 62., 37.],
#        [32., 65., 37.],
#        [33., 60., 37.],
#        ...,
#        [93., 69., 38.],
#        [93., 70., 37.],
#        [93., 70., 38.]], dtype=float32)>

# %%
t = tf.cast(tf.transpose(x[0:3]),dtype=tf.int32)

s = t.numpy()

array_of_tuples = map(tuple, s)

tuple_of_tuples = tuple(array_of_tuples)

print(tuple_of_tuples)
# Out:
# ((32, 32, 33), (62, 65, 60), (37, 37, 37))

# %%
tuple_of_tuples
# Out:
# ((32, 32, 33), (62, 65, 60), (37, 37, 37))

# %%
z = x - y

# %%
z
# Out:
# <tf.Tensor: shape=(81257, 3), dtype=float32, numpy=
# array([[-32.,  -2., -27.],
#        [-32.,   1., -27.],
#        [-31.,  -4., -27.],
#        ...,
#        [ 29.,   5., -26.],
#        [ 29.,   6., -27.],
#        [ 29.,   6., -26.]], dtype=float32)>

# %%
q = tf.constant([-1,1,1],dtype= tf.float32)

# %%
z*q
# Out:
# <tf.Tensor: shape=(81257, 3), dtype=float32, numpy=
# array([[ 32.,  -2., -27.],
#        [ 32.,   1., -27.],
#        [ 31.,  -4., -27.],
#        ...,
#        [-29.,   5., -26.],
#        [-29.,   6., -27.],
#        [-29.,   6., -26.]], dtype=float32)>

# %%
w = tf.where(z <= 0, 0,z)

# %%
w[~np.all(w == 0, axis=1)]
# Out:
# <tf.Tensor: shape=(68343, 3), dtype=float32, numpy=
# array([[ 0.,  1.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  3.,  0.],
#        ...,
#        [29.,  5.,  0.],
#        [29.,  6.,  0.],
#        [29.,  6.,  0.]], dtype=float32)>

# %%
~np.all(w == 0, axis=1)
# Out:
# array([False,  True, False, ...,  True,  True,  True])

# %%
x[0]
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([32., 62., 37.], dtype=float32)>

# %%
tfg.geometry.transformation.axis_angle.rotate(x,axis,angle)
# Out:
# <tf.Tensor: shape=(81257, 3), dtype=float32, numpy=
# array([[-62.000114,  31.999775,  37.      ],
#        [-65.000114,  31.999765,  37.      ],
#        [-60.00012 ,  32.999783,  37.      ],
#        ...,
#        [-69.000336,  92.99975 ,  38.      ],
#        [-70.000336,  92.99975 ,  37.      ],
#        [-70.000336,  92.99975 ,  38.      ]], dtype=float32)>

# %%
x[0]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([32, 32, 33], dtype=int32)>

# %%
point = tf.constant([[1,0,0],[0,1,0]],dtype=tf.float32)  # point
axis = tf.constant([[0,0,1],[1,0,0]],dtype=tf.float32) # Cartesians coordenates
angle = tf.constant([[3.1416],[3.1416/4]],dtype=tf.float32)  # Radians Angles
tfg.geometry.transformation.axis_angle.rotate(point,axis,angle)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[-1.0000000e+00, -7.2399803e-06,  0.0000000e+00],
#        [ 0.0000000e+00,  7.0710546e-01,  7.0710808e-01]], dtype=float32)>

# %%
point = tf.constant([[1,0,0],[0,1,0]],dtype=tf.float32)  # point
axis = tf.constant([0,0,1],dtype=tf.float32) # Cartesians coordenates
angle = tf.constant([3.1416/2],dtype=tf.float32)  # Radians Angles
tfg.geometry.transformation.axis_angle.rotate(point,axis,angle)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[-3.6199901e-06,  1.0000000e+00,  0.0000000e+00],
#        [-1.0000000e+00, -3.6199901e-06,  0.0000000e+00]], dtype=float32)>

# %%
point = tf.constant([1,0,0],dtype=tf.float32)  # point
axis = tf.constant([0,0,1],dtype=tf.float32) # Cartesians coordenates
angle = tf.constant([3.1416/2],dtype=tf.float32)  # Radians Angles
tfg.geometry.transformation.axis_angle.rotate(point,axis,angle)
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([-3.6199901e-06,  1.0000000e+00,  0.0000000e+00], dtype=float32)>

# %%
point = tf.constant([[1,0,0],[0,1,0]],dtype=tf.float32)  # point
axis = tf.constant([0,0,1],dtype=tf.float32) # Cartesians coordenates
angle = tf.constant([3.1416/2],dtype=tf.float32)  # Radians Angles
r = tf.cast(tfg.geometry.transformation.axis_angle.rotate(point,axis,angle),dtype=tf.int32)

# %%
r
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 0,  1,  0],
#        [-1,  0,  0]], dtype=int32)>

# %%
r.numpy()
# Out:
# array([[ 0,  1,  0],
#        [-1,  0,  0]], dtype=int32)

# %%
import os
ct,masks,possible_dose_mask,voxel_dimensions = load_images_to_net_test("/content/validation-pats-no-dose/pt_204")

# %%
np.ravel(ct,order="C")
# Out:
# array([-1., -1., -1., ..., -1., -1., -1.], dtype=float32)

# %%
t = tf.transpose(r)

s = t.numpy()

array_of_tuples = map(tuple, s)

tuple_of_tuples = tuple(array_of_tuples)

print(tuple_of_tuples)
# Out:
# ((0, -1), (1, 0), (0, 0))
